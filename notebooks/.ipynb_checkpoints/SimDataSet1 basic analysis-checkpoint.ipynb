# %% [markdown]
# prepared by Alex Bombrun 15/04/2018
#
# ballTree

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mp
import astropy.units as u

# %%
mp.rcParams['figure.figsize'] = (12, 8)

# %%
ls /Users/abombrun/Documents/GitHub/StatClub
# Out:
# ALLwise QSO vizier.ipynb
# Known lensed QSO Castles.ipynb
# QSO DR1 errors and DR2 error model.ipynb
# README.md
# StrongLensDemo.ipynb
# lensedQSO.csv
# simDataSet0.csv.gzip

# %%
d = pd.read_csv("/Users/abombrun/Documents/GitHub/StatClub/simDataSet0.csv.gzip",compression='gzip')

# %% [markdown]
# with DR2 date one should take in account the correlation

# %%
d['mu'] = np.sqrt(np.power(d.pmra,2)+np.power(d.pmdec,2))
d['mu_error'] = np.sqrt(np.power(d.pmra_error,2)+np.power(d.pmdec_error,2))
d['mu_norm'] = d.mu/d.mu_error

# %%
d.groupby(d.type).mu.count()
# Out:
# type
# QSO     393907
# STAR     23336
# lens       260
# Name: mu, dtype: int64

# %%
d.groupby(d.type)['astrometric_pseudo_colour','phot_g_mean_mag','mu','mu_error','mu_norm'].median()
# Out:
#       astrometric_pseudo_colour  phot_g_mean_mag         mu  mu_error  \
# type
# QSO                    1.700040        19.238500   0.870961  1.079246
# STAR                   1.600284        18.381000  10.826819  0.645173
# lens                   1.596547        18.890436   0.179727  0.875893
#
#         mu_norm
# type
# QSO    0.833535
# STAR  18.651549
# lens   0.206354

# %%
for k,g in d.groupby(d.type):
    g.mu_norm.hist(bins=100,alpha=0.5,range=(0,10),normed=True,label=k)
plt.legend()
plt.xlabel("mu [mas/yr]")
# Out:
# Text(0.5,0,'mu [mas/yr]')

# %%
for k,g in d.groupby(d.type):
    g.mu.hist(bins=100,alpha=0.5,range=(0,2),normed=True,label=k)
plt.legend()
plt.xlabel("mu [mas/yr]")
# Out:
# Text(0.5,0,'mu [mas/yr]')

# %%
for k,g in d.groupby(d.type):
    g.phot_g_mean_mag.hist(bins=100,alpha=0.5,range=(10,22),normed=True,label=k)
plt.legend()
plt.xlabel("g [mag]")
# Out:
# Text(0.5,0,'g [mag]')

# %%
for k,g in d.groupby(d.type):
    g.mu_norm.hist(bins=100,alpha=0.5,range=(0,10),normed=True,label=k)
plt.legend()
plt.xlabel("mu / mu_error")
# Out:
# Text(0.5,0,'mu / mu_error')

# %% [markdown]
# # the lens

# %%
lensqsoid = np.unique(d[d.type=='lens'].qsoid.values)

# %%
s = d[d.qsoid==lensqsoid[0]]

# %%
s
# Out:
#                Unnamed: 0         ra  ra_error       dec  dec_error  parallax  \
# 417305  14977130110446140  45.790950  0.056006  9.621768   0.056006 -0.090993
# 417306  14977129766340306  45.790951  0.163324  9.621767   0.163324  0.116092
#
#         parallax_error      pmra  pmra_error     pmdec  pmdec_error  \
# 417305        0.058621  0.330686    0.094273 -0.977815     0.094273
# 417306        0.143233 -0.230221    0.258277  0.144328     0.258277
#
#         phot_g_mean_mag          source_id  astrometric_pseudo_colour  \
# 417305        15.753089  14977130110446140                   1.550700
# 417306        17.432812  14977129766340306                   1.599139
#
#                     qsoid  type        mu  mu_error   mu_norm
# 417305  14977130110446140  lens  1.032219  0.133323  7.742264
# 417306  14977130110446140  lens  0.271721  0.365258  0.743915

# %%
s.columns
# Out:
# Index(['Unnamed: 0', 'ra', 'ra_error', 'dec', 'dec_error', 'parallax',
#        'parallax_error', 'pmra', 'pmra_error', 'pmdec', 'pmdec_error',
#        'phot_g_mean_mag', 'source_id', 'astrometric_pseudo_colour', 'qsoid',
#        'type', 'mu', 'mu_error', 'mu_norm'],
#       dtype='object')

# %%
def plotLens(d,qsoid):
    s = d[d.qsoid==qsoid]
    x = (s.ra - s.ra.median())*u.deg.to(u.mas)
    y = (s.dec - s.dec.median())*u.deg.to(u.mas)
    plt.scatter(x,y,s = s.phot_g_mean_mag)
    plt.quiver(x,y,s.pmra,s.pmdec)
    plt.grid()
    plt.xlim(-2,2)
    plt.ylim(-2,2)
    
def plotGaiaLens(d,qsoid,r=(-5,5),pm=True,pmscale=1):
    s = d[d.qsoid==qsoid]
    x = (s.ra - s.ra.median())*u.deg.to(u.mas)
    y = (s.dec - s.dec.median())*u.deg.to(u.mas)
    plt.errorbar(x,y,xerr=s.ra_error, yerr=s.dec_error,fmt='.')
    plt.scatter(x,y,s=100*np.exp(20-s.phot_g_mean_mag),c=s.astrometric_pseudo_colour)
    plt.colorbar(label="nuEff")
    if pm : 
        vx = s.pmra*pmscale
        vy = s.pmdec*pmscale
        plt.quiver(x,y, vx, vy)#note the pm are in mas, angles='xy', scale_units='xy', scale=1)
        plt.errorbar(x+vx,y+vy,xerr=s.pmra_error, yerr=s.pmdec_error,fmt='o')
    plt.grid()
    plt.xlabel("gaia.ra - center [mas]")
    plt.ylabel("gaia.dec - center [mas]")
    plt.xlim(r)
    plt.ylim(r)

# %%
plotLens(d,lensqsoid[60])

# %%
s.pmra_error
# Out:
# 417305    0.094273
# 417306    0.258277
# Name: pmra_error, dtype: float64

# %%
plotGaiaLens(d,lensqsoid[3])

# %%
plotGaiaLens(d,lensqsoid[3],pmscale=20)

# %%
plotGaiaLens(d,lensqsoid[6],pmscale=2)

# %%
plotGaiaLens(d,lensqsoid[9],pmscale=5)

# %% [markdown]
# lens with the largest apparent proper motion

# %%
d[d.index==d[d.type=='lens'].mu.idxmax()].qsoid
# Out:
# 417389    4732918161983100968
# Name: qsoid, dtype: int64

# %%
plotGaiaLens(d,4732918161983100968,r=(-10,10))
