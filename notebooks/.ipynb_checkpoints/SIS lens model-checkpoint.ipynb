# %% [markdown]
# Alex Bombrun 24/03/2018

# %% [markdown]
# A notebook to generate random lensed QSOs to illustrate proper motion magnification. With Gaia DR2 one might expect to have for the first time some proper motion in strong lensed QSOs.
#
# If $dy$ is the proper motion of a source at $y$ one get the proper motion magnification in each image as $dx = A^{-1} dy$, where $A$ is the distortion matrix a the location of the image $x$.
#
# This notebook is based on the SIE lens model. There are many other different lens models. Similar consideration might be applied to any lens models that defined image location and distortion matrix.

# %% [markdown]
# # SIS : limit of SIE model
#
# The SIE model was introduced in Kormann, Schneider & Bartelmann (1994) http://adsabs.harvard.edu/abs/1994A%26A...284..285K

# %% [markdown]
# ### SIS model
# $$\kappa =  \frac{1}{2\,x}$$
# $$\alpha = \frac{x}{|x|}$$
# $$ x = y - \frac{x}{|x|}$$
#
# $$x=(r,\varphi)$$
#
# $$ r \cos{\varphi} \, e_1 + r \sin{\varphi} \, e_2 =  (y_1- \cos{\varphi}) \, e_1 + (y_2- \sin{\varphi}) \, e_2 $$
#
# $$ r = (y_1- \cos{\varphi})\cos{\varphi} + (y_2- \sin{\varphi})\sin{\varphi} $$
#
#
# $$(y_1 + \cos{\varphi})\sin{\varphi} - (y_2 + \sin{\varphi})\cos{\varphi} = 0$$

# %%
from context import lens
import lens.sis.model as sis

# %%
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt

from scipy import optimize
from scipy.misc import derivative

import pandas as pd
import astropy.units as u

# %matplotlib inline

# %%
mp.rcParams['figure.figsize']=[12,8]

# %%
def circle(r = 0.01) :
    """
    define a circle of radius r center on 0,0 in cartesian coordinate
    r : radius
    return : [x,y] an numpy array of length [2,20], 20 equidistant points on the circle
    """
    theta =  np.pi*np.arange(0,2,0.1)
    dy1 = r*np.cos(theta)
    dy2 = r*np.sin(theta)
    return np.array([dy1,dy2])

def plotLens(ax,color='C0'):
    """
    plot the SIE lens cut and caustic curve defined by f in the axis ax
    f :  lens parameter
    ax : matplotlib axis
    """
    theta =  np.pi*np.arange(0,2,0.001)
    xy = sis.cut(theta)
    ax.plot(xy[0],xy[1],color=color,label='cut')
    
def plotSourceImage(y1,y2,ax = plt.subplot(111,aspect='equal')):
    """
    plot the images of the source y1,y2 through the SIE lens defined by f in the axis ax
    y1,y2 : source position relative to the lens
    f : SIE lens parameter
    ax : matplotlib axis
    """
    phis,xs = sis.solve(y1,y2)
    dy =  circle(0.1)
    for phi,x in zip(phis,xs) :
        dx = np.dot(np.linalg.inv(sis.A(x,phi)),dy)
        x1 = x*np.cos(phi)
        x2 = x*np.sin(phi)
        ax.scatter(x1,x2,color='C0')#s = np.exp(np.abs(mag(x,phi,f)))
        ax.scatter(x1+dx[0],x2+dx[1],s=1,color='C0')
        ax.plot([x1,x1+dx[0][0]],[x2,x2+dx[1][0]],color='C0')
    ax.scatter(y1,y2,s=np.exp(1),label="source",color='C1')
    ax.scatter(y1+dy[0],y2+dy[1],color='C1',s=1)
    ax.plot([y1,y1+dy[0][0]],[y2,y2+dy[1][0]],color='C1')
    ax.grid()   
    
def plotLensSourceImage(y1,y2):
    ax = plt.subplot(221,aspect='equal')
    plotLens(ax)
    ax.scatter(y1,y2,label="source",color='C1')
    plt.grid()
    plt.legend()
    ax = plt.subplot(222,aspect='equal')
    plotSourceImage(y1,y2,ax=ax)

# %%
ax = plt.subplot(111,aspect='equal')
plotLens(ax,color='C0')
plt.grid()
plt.legend()
plt.xlim(-2,2)
# Out:
# (-2, 2)

# %%
y1=0.1
y2=0.2
eq = lambda phi : sis.eq2(phi,y1,y2)

ax = plt.subplot(111,aspect='equal')
plotLens(ax)
ax.scatter(y1,y2,label="source",color='C1')
plt.grid()
plt.legend()

# %% [markdown]
# to visualise the lens equation

# %%
plt.subplot(221)
x =  np.arange(-1e4,1e4,0.1)
plt.plot(x,np.arcsinh(x))
plt.subplot(222)
x =  np.arange(-1,1,0.01)
y = np.arcsin(x)
plt.plot(x,y)

plt.subplot(223)
phi = np.arange(0,2*np.pi,0.01)
plt.plot(phi,eq(phi),label='eq')
plt.plot(phi,derivative(eq, phi, dx=1e-4),label='eq\'')
plt.grid()
plt.legend()

# %%
data = y1,y2
phis,xs = sis.solve(*data)
print(phis,xs)
# Out:
# [1.10714872 4.24874137] [1.2236068 0.7763932]

# %% [markdown]
# plot lens

# %%
ax = plt.subplot(111,aspect='equal')
ax.scatter(xs*np.cos(phis),xs*np.sin(phis),s = np.exp(sis.magnification(xs,phis)))
ax.scatter(y1,y2,s=np.exp(1),label="source")
plt.grid()
plt.legend()

# %% [markdown]
# test magnification

# %%
As = sis.A(xs,phis)
magnifications = [1/np.linalg.det(As[:,:,i]) for i in np.arange(0,len(phis))]
magnifications - sis.magnification(xs,phis)
# Out:
# array([ 8.88178420e-16, -1.33226763e-15])

# %% [markdown]
# proper motion

# %%
dy = np.array([0.01,0.01])

# %%
np.dot(np.linalg.inv(As[:,:,0]),dy)
# Out:
# array([0.02788854, 0.00105573])

# %%
[np.dot(np.linalg.inv(As[:,:,i]),dy) for i in np.arange(0,len(phis))]
# Out:
# [array([0.02788854, 0.00105573]), array([-0.00788854,  0.01894427])]

# %%
dy =  circle()

# %%
plotLensSourceImage(0.1,0.6)

# %%
plotLensSourceImage(0.2,0.6)

# %%
plotLensSourceImage(0.3,0.6)

# %%
plotLensSourceImage(0.6,0.6)

# %%
plotLensSourceImage(0.7,0.7)

# %%
plotLensSourceImage(0.1,0.1)

# %%
plotLensSourceImage(0.2,0.2)

# %%
plotLensSourceImage(0.3,0.3)

# %%
plotLensSourceImage(0.4,0.4)

# %%
plotLensSourceImage(0.5,0.5)

# %%
plotLensSourceImage(0.1,0)

# %%
plotLensSourceImage(0,0.1)
